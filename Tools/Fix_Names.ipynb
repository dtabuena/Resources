# %% [markdown]
# <a href="https://colab.research.google.com/github/dtabuena/Resources/blob/main/Tools/Fix_Names.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pandas as pd
import shutil


source_dir = r"\\hive.gladstone.internal\Huang-Lab\Lab Members\Tabuena_Main\0_Projects_hv\_PatchSeq_DGC\Recordings"
print(source_dir)

os.chdir(source_dir)
file_list =list()


for root, dirs, files in os.walk(".", topdown=False):
    for file in files:
        if  True : # 'abf' in file:
            file_list.append(os.path.join(root,file))
# _ = [print(f) for f in file_list]
# print(file_list)
print(len(file_list))
# Out:
# \\hive.gladstone.internal\Huang-Lab\Lab Members\Tabuena_Main\0_Projects_hv\_PatchSeq_DGC\Recordings
# 9762

# %%
def convert(file_path):
    dir_name = os.path.dirname(file_path)
    base = os.path.basename(file_path)

    base = base.replace(r'2024x04x25_E3KI_F_P599_sagi_s004_c007_DG', r'2024x04x25_E3KI_F_P599_sagi_s004_c007_DGC')
    # base = base.replace(r'2024x04x26_E3KI_F_P591_sagi_', r'2024x04x26_E3KI_F_P600_sagi_')
    # base = base.replace(r'2024x04x29_E3KI_F_P594_sagi_', r'2024x04x29_E3KI_F_P603_sagi_')
    # base = base.replace(r'2024x05x01_E3KI_F_P596_sagi_s', r'2024x05x01_E3KI_F_P605_sagi_s')
    # base = base.replace(r'24x05x03_E3KI_F_P598_sagi', r'24x05x03_E3KI_F_P607_sagi')
    # base = base.replace(r'2024x05x08_E3KI_F_P256_sagi', r'2024x05x08_E3KI_F_P260_sagi')
    # base = base.replace(r'2024x05x09_E3KI_F_P257_sagi_s', r'2024x05x09_E3KI_F_P261_sagi_s')
    # base = base.replace(r'2024x05x10_E3KI_F_P258_sagi_', r'2024x05x10_E3KI_F_P262_sagi_')
    # base = base.replace(r'2024x05x13_E3KI_F_P261_sagi', r'2024x05x13_E3KI_F_P265_sagi')
    # base = base.replace(r'2024x05x15_E4KI_F_P270_sagi_s002_c003_DGC', r'2024x05x15_E4KI_F_P270_sagi_s002_c004_DGC')
    # base = base.replace(r'2024x05x15_E4KI_F_P270', r'2024x05x15_E4KI_F_P274')
    # base = base.replace(r'2024x05x16_E4KI_F_P587_sagi_', r'2024x05x16_E4KI_F_P596_sagi_')
    # base = base.replace(r'2024x05x17_E4KI_F_P589_sa', r'2024x05x17_E4KI_F_P598_sa')
    # base = base.replace(r'2024x09x13_E4KI_F_P590_sagi_s001_c002_DGC', r'2024x09x13_E4KI_F_P590_sagi_s002_c002_DGC')
    # base = base.replace(r'2024x09x13_E4KI_F_P590_sagi_s001_c003_DGC', r'2024x09x13_E4KI_F_P590_sagi_s002_c003_DGC')
    # base = base.replace(r'2024x09x13_E4KI_F_P590_sagi_s001_c004_DGC', r'2024x09x13_E4KI_F_P590_sagi_s002_c004_DGC')
    # base = base.replace(r'2024x09x16_fE4KIxSynCre_F_P256_sagi_s003_c004_DGC', r'2024x09x16_fE4KIxSynCre_F_P256_sagi_s002_c004_DGC')
    # base = base.replace(r'2024x09x19_fE4KIxSynCre_F_P630_sagi_s001_c002_DGC', r'2024x09x19_fE4KIxSynCre_F_P630_sagi_s002_c002_DGC')
    # base = base.replace(r'2024x12x04_E4KI_F_P275_sagi_s001_c002_DGC', r'2024x12x04_E4KI_F_P275_sagi_s002_c002_DGC')
    # base = base.replace(r'2025x08x22_E3KI_F_P254_sagi_s002_c004_DGC', r'2025x08x22_E3KI_F_P254_sagi_s003_c004_DGC')

    return os.path.join(dir_name, base)

file_conversion_dict = {f:convert(f) for f in file_list}
print('New Files:')
# display(file_conversion_dict)
for old,new in file_conversion_dict.items():
    if old not in new:
        print(new,'\n','from',old,'\n'*2)
file_conversion_dict = {k:v for k,v in file_conversion_dict.items() if k != v}
print(len(file_conversion_dict))
# Out:
# New Files:
# .\Saved_Figs\Membrane_Fit_PC\Membrane_Fit_PC_2024x04x25_E3KI_F_P599_sagi_s004_c007_DGCC_0008.png
#  from .\Saved_Figs\Membrane_Fit_PC\Membrane_Fit_PC_2024x04x25_E3KI_F_P599_sagi_s004_c007_DGC_0008.png
#
#
# .\Saved_Figs\Membrane_Fit_PC\Membrane_Fit_PC_2024x04x25_E3KI_F_P599_sagi_s004_c007_DGCC_0000.png
#  from .\Saved_Figs\Membrane_Fit_PC\Membrane_Fit_PC_2024x04x25_E3KI_F_P599_sagi_s004_c007_DGC_0000.png
#
#
# .\Saved_Figs\Membrane_Fit_PC\Membrane_Fit_PC_2024x04x25_E3KI_F_P599_sagi_s004_c007_DGCC_0009.png
#  from .\Saved_Figs\Membrane_Fit_PC\Membrane_Fit_PC_2024x04x25_E3KI_F_P599_sagi_s004_c007_DGC_0009.png
#
#
# .\Saved_Figs\Input_Resitance\Ih_Sag_2024x04x25_E3KI_F_P599_sagi_s004_c007_DGCC_0007.jpg
#  from .\Saved_Figs\Input_Resitance\Ih_Sag_2024x04x25_E3KI_F_P599_sagi_s004_c007_DGC_0007.jpg
#
#
# .\Saved_Figs\Input_Resitance\Input_Resitance_2024x04x25_E3KI_F_P599_sagi_s004_c007_DGCC_0007.jpg
#  from .\Saved_Figs\Input_Resitance\Input_Resitance_2024x04x25_E3KI_F_P599_sagi_s004_c007_DGC_0007.jpg
#
#
# .\Saved_Figs\IV_Curves\IV_Curves_2024x04x25_E3KI_F_P599_sagi_s004_c007_DGCC_0002.jpg
#  from .\Saved_Figs\IV_Curves\IV_Curves_2024x04x25_E3KI_F_P599_sagi_s004_c007_DGC_0002.jpg
#
#
# .\Saved_Figs\Resting_VM\Resting_VM_2024x04x25_E3KI_F_P599_sagi_s004_c007_DGCC_0001.jpg
#  from .\Saved_Figs\Resting_VM\Resting_VM_2024x04x25_E3KI_F_P599_sagi_s004_c007_DGC_0001.jpg
#
#
# .\Saved_Figs\Rheobase\Rheobase_2024x04x25_E3KI_F_P599_sagi_s004_c007_DGCC_0005.jpg
#  from .\Saved_Figs\Rheobase\Rheobase_2024x04x25_E3KI_F_P599_sagi_s004_c007_DGC_0005.jpg
#
#
# .\Saved_Figs\AP_Params\AP_Params_2024x04x25_E3KI_F_P599_sagi_s004_c007_DGCC_0005.png
#  from .\Saved_Figs\AP_Params\AP_Params_2024x04x25_E3KI_F_P599_sagi_s004_c007_DGC_0005.png
#
#
# .\Saved_Figs\Membrane_Fit\Membrane_Fit_2024x04x25_E3KI_F_P599_sagi_s004_c007_DGCC_0000.png
#  from .\Saved_Figs\Membrane_Fit\Membrane_Fit_2024x04x25_E3KI_F_P599_sagi_s004_c007_DGC_0000.png
#
#
# .\Saved_Figs\Membrane_Fit\Membrane_Fit_2024x04x25_E3KI_F_P599_sagi_s004_c007_DGCC_0009.png
#  from .\Saved_Figs\Membrane_Fit\Membrane_Fit_2024x04x25_E3KI_F_P599_sagi_s004_c007_DGC_0009.png
#
#
# .\Saved_Figs\Membrane_Fit\Membrane_Fit_2024x04x25_E3KI_F_P599_sagi_s004_c007_DGCC_0008.png
#  from .\Saved_Figs\Membrane_Fit\Membrane_Fit_2024x04x25_E3KI_F_P599_sagi_s004_c007_DGC_0008.png
#
#
# .\Saved_Figs\Firing_Gain\Firing_Gain_2024x04x25_E3KI_F_P599_sagi_s004_c007_DGCC_0004jpg.png
#  from .\Saved_Figs\Firing_Gain\Firing_Gain_2024x04x25_E3KI_F_P599_sagi_s004_c007_DGC_0004jpg.png
#
#
# .\Saved_Figs\Firing_Gain\Adaption_2024x04x25_E3KI_F_P599_sagi_s004_c007_DGCC_0004.jpg
#  from .\Saved_Figs\Firing_Gain\Adaption_2024x04x25_E3KI_F_P599_sagi_s004_c007_DGC_0004.jpg
#
#
# .\Saved_Figs\Firing_Gain\Phase_2024x04x25_E3KI_F_P599_sagi_s004_c007_DGCC_0004.jpg
#  from .\Saved_Figs\Firing_Gain\Phase_2024x04x25_E3KI_F_P599_sagi_s004_c007_DGC_0004.jpg
#
#
# .\Saved_Figs\Firing_Gain\Slow_After_Hyperpolarization_2024x04x25_E3KI_F_P599_sagi_s004_c007_DGCC_0004.jpg
#  from .\Saved_Figs\Firing_Gain\Slow_After_Hyperpolarization_2024x04x25_E3KI_F_P599_sagi_s004_c007_DGC_0004.jpg
#
#
# .\Saved_Figs\Spike_latency\Spike_latency_2024x04x25_E3KI_F_P599_sagi_s004_c007_DGCC_0006.jpg
#  from .\Saved_Figs\Spike_latency\Spike_latency_2024x04x25_E3KI_F_P599_sagi_s004_c007_DGC_0006.jpg
#
#
# .\2024x04x25\2024x04x25_E3KI_F_P590_sagi_s004_c007_DG\2024x04x25_E3KI_F_P599_sagi_s004_c007_DGCC_MMStack_Default.ome.tif
#  from .\2024x04x25\2024x04x25_E3KI_F_P590_sagi_s004_c007_DG\2024x04x25_E3KI_F_P599_sagi_s004_c007_DGC_MMStack_Default.ome.tif
#
#
# .\2024x04x25\2024x04x25_E3KI_F_P590_sagi_s004_c007_DG\2024x04x25_E3KI_F_P599_sagi_s004_c007_DGCC_MMStack_Default_metadata.txt
#  from .\2024x04x25\2024x04x25_E3KI_F_P590_sagi_s004_c007_DG\2024x04x25_E3KI_F_P599_sagi_s004_c007_DGC_MMStack_Default_metadata.txt
#
#
# .\2024x04x25\2024x04x25_E3KI_F_P599_sagi_s004_c007_DGCC_0009.abf
#  from .\2024x04x25\2024x04x25_E3KI_F_P599_sagi_s004_c007_DGC_0009.abf
#
#
# .\2024x04x25\2024x04x25_E3KI_F_P599_sagi_s004_c007_DGCC_0000.abf
#  from .\2024x04x25\2024x04x25_E3KI_F_P599_sagi_s004_c007_DGC_0000.abf
#
#
# .\2024x04x25\2024x04x25_E3KI_F_P599_sagi_s004_c007_DGCC_0007.abf
#  from .\2024x04x25\2024x04x25_E3KI_F_P599_sagi_s004_c007_DGC_0007.abf
#
#
# .\2024x04x25\2024x04x25_E3KI_F_P599_sagi_s004_c007_DGCC_0004.abf
#  from .\2024x04x25\2024x04x25_E3KI_F_P599_sagi_s004_c007_DGC_0004.abf
#
#
# .\2024x04x25\2024x04x25_E3KI_F_P599_sagi_s004_c007_DGCC_0001.abf
#  from .\2024x04x25\2024x04x25_E3KI_F_P599_sagi_s004_c007_DGC_0001.abf
#
#
# .\2024x04x25\2024x04x25_E3KI_F_P599_sagi_s004_c007_DGCC_0003.abf
#  from .\2024x04x25\2024x04x25_E3KI_F_P599_sagi_s004_c007_DGC_0003.abf
#
#
# .\2024x04x25\2024x04x25_E3KI_F_P599_sagi_s004_c007_DGCC_0005.abf
#  from .\2024x04x25\2024x04x25_E3KI_F_P599_sagi_s004_c007_DGC_0005.abf
#
#
# .\2024x04x25\2024x04x25_E3KI_F_P599_sagi_s004_c007_DGCC_0002.abf
#  from .\2024x04x25\2024x04x25_E3KI_F_P599_sagi_s004_c007_DGC_0002.abf
#
#
# .\2024x04x25\2024x04x25_E3KI_F_P599_sagi_s004_c007_DGCC_0008.abf
#  from .\2024x04x25\2024x04x25_E3KI_F_P599_sagi_s004_c007_DGC_0008.abf
#
#
# .\2024x04x25\2024x04x25_E3KI_F_P599_sagi_s004_c007_DGCC_0006.abf
#  from .\2024x04x25\2024x04x25_E3KI_F_P599_sagi_s004_c007_DGC_0006.abf
#
#
# 29

# %%
from tqdm import tqdm
os.chdir(source_dir)

for src, dst in tqdm(file_conversion_dict.items()):
    os.rename(src, dst)
# Out:
# 0it [00:00, ?it/s]
