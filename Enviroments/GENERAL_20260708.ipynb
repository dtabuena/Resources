# %% [markdown]
# <a href="https://colab.research.google.com/github/dtabuena/Resources/blob/main/Enviroments/GENERAL_20260708.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# $ conda create -n GENERAL_20260708

# %%
# !pip install --force-reinstall numpy==2.4.6 networkx==3.6.1 matplotlib==3.10.9 gprofiler-official==1.0.0 gseapy==1.3.0 h5py==3.16.0 colorspacious==1.1.2 goatools==1.6.5 pandas==3.0.3 pyabf==2.3.8 pybiomart==0.2.0 pynndescent==0.6.0 scanpy==1.12.2 scikit-learn==1.9.0 scipy==1.18.0 seaborn==0.13.2 statsmodels==0.14.6 tqdm==4.68.4 xlsxwriter==3.2.9
# Out:
# ...
#   Using cached numpy-2.4.6-cp314-cp314-win_amd64.whl.metadata (6.6 kB)
# ...
#   Using cached networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# ...
#   Using cached matplotlib-3.10.9-cp314-cp314-win_amd64.whl.metadata (52 kB)
# ...
#   Using cached gprofiler_official-1.0.0-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached gseapy-1.3.0-cp314-cp314-win_amd64.whl.metadata (13 kB)
# ...
#   Using cached h5py-3.16.0-cp314-cp314-win_amd64.whl.metadata (3.1 kB)
# ...
#   Using cached colorspacious-1.1.2-py2.py3-none-any.whl.metadata (3.6 kB)
# ...
#   Using cached goatools-1.6.5-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached pandas-3.0.3-cp314-cp314-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached pyabf-2.3.8-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached pybiomart-0.2.0-py3-none-any.whl.metadata (1.1 kB)
# ...
#   Using cached pynndescent-0.6.0-py3-none-any.whl.metadata (6.9 kB)
# ...
#   Using cached scanpy-1.12.2-py3-none-any.whl.metadata (8.5 kB)
# ...
