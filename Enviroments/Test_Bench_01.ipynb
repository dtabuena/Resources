# %% [markdown]
# <a href="https://colab.research.google.com/github/dtabuena/Resources/blob/main/Enviroments/Test_Bench_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. conda create -n Test_Bench_01
# 2. (Optional) Use navigator to install ipynb or other editor
# 3. Run the pip install

# %%
# !pip install --force-reinstall numpy==2.4.6 networkx==3.6.1 matplotlib==3.10.9 gprofiler-official==1.0.0 gseapy==1.3.0 h5py==3.16.0 colorspacious==1.1.2 goatools==1.6.5 pandas==3.0.3 pyabf==2.3.8 pybiomart==0.2.0 pynndescent==0.6.0 scanpy==1.12.2 scikit-learn==1.9.0 scipy==1.18.0 seaborn==0.13.2 statsmodels==0.14.6 tqdm==4.68.4 xlsxwriter==3.2.9
