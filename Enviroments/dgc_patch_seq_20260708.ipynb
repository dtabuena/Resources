# %% [markdown]
# <a href="https://colab.research.google.com/github/dtabuena/Resources/blob/main/Enviroments/dgc_patch_seq_20260708.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# $ conda create -n dgc_patch_seq_20260708

# %%
# !pip install --force-reinstall numpy==2.4.6 networkx==3.6.1 matplotlib==3.10.9 gprofiler-official==1.0.0 gseapy==1.3.0 h5py==3.16.0 colorspacious==1.1.2 goatools==1.6.5 pandas==3.0.3 pyabf==2.3.8 pybiomart==0.2.0 pynndescent==0.6.0 scanpy==1.12.2 scikit-learn==1.9.0 scipy==1.18.0 seaborn==0.13.2 statsmodels==0.14.6 tqdm==4.68.4 xlsxwriter==3.2.9

# %%
# !pip install https://github.com/dtabuena/patchclamp_analysis/archive/main.zip --upgrade --no-cache-dir
# Out:
# Collecting https://github.com/dtabuena/patchclamp_analysis/archive/main.zip
#   Downloading main.zip
#      - 0 bytes ? 0:00:00
#      - 43.9 kB 1.1 MB/s 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy>=1.24 in .\AppData\Local\anaconda3\envs\dgc_patch_seq_20260708\Lib\site-packages (from patchclamp_analysis==0.1.0) (2.4.6)
# Requirement already satisfied: scipy<2.0,>=1.12 in .\AppData\Local\anaconda3\envs\dgc_patch_seq_20260708\Lib\site-packages (from patchclamp_analysis==0.1.0) (1.17.1)
# Requirement already satisfied: matplotlib<4.0,>=3.7 in .\AppData\Local\anaconda3\envs\dgc_patch_seq_20260708\Lib\site-packages (from patchclamp_analysis==0.1.0) (3.10.9)
# Requirement already satisfied: pyabf<3.0,>=2.3 in .\AppData\Local\anaconda3\envs\dgc_patch_seq_20260708\Lib\site-packages (from patchclamp_analysis==0.1.0) (2.3.8)
# Requirement already satisfied: pandas<3.0,>=1.5 in .\AppData\Local\anaconda3\envs\dgc_patch_seq_20260708\Lib\site-packages (from patchclamp_analysis==0.1.0) (2.3.3)
# Requirement already satisfied: contourpy>=1.0.1 in .\AppData\Local\anaconda3\envs\dgc_patch_seq_20260708\Lib\site-packages (from matplotlib<4.0,>=3.7->patchclamp_analysis==0.1.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in .\AppData\Local\anaconda3\envs\dgc_patch_seq_20260708\Lib\site-packages (from matplotlib<4.0,>=3.7->patchclamp_analysis==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in .\AppData\Local\anaconda3\envs\dgc_patch_seq_20260708\Lib\site-packages (from matplotlib<4.0,>=3.7->patchclamp_analysis==0.1.0) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in .\AppData\Local\anaconda3\envs\dgc_patch_seq_20260708\Lib\site-packages (from matplotlib<4.0,>=3.7->patchclamp_analysis==0.1.0) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in .\AppData\Local\anaconda3\envs\dgc_patch_seq_20260708\Lib\site-packages (from matplotlib<4.0,>=3.7->patchclamp_analysis==0.1.0) (26.2)
# Requirement already satisfied: pillow>=8 in .\AppData\Local\anaconda3\envs\dgc_patch_seq_20260708\Lib\site-packages (from matplotlib<4.0,>=3.7->patchclamp_analysis==0.1.0) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in .\AppData\Local\anaconda3\envs\dgc_patch_seq_20260708\Lib\site-packages (from matplotlib<4.0,>=3.7->patchclamp_analysis==0.1.0) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in .\AppData\Local\anaconda3\envs\dgc_patch_seq_20260708\Lib\site-packages (from matplotlib<4.0,>=3.7->patchclamp_analysis==0.1.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in .\AppData\Local\anaconda3\envs\dgc_patch_seq_20260708\Lib\site-packages (from pandas<3.0,>=1.5->patchclamp_analysis==0.1.0) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in .\AppData\Local\anaconda3\envs\dgc_patch_seq_20260708\Lib\site-packages (from pandas<3.0,>=1.5->patchclamp_analysis==0.1.0) (2026.2)
# Requirement already satisfied: pytest>=3.0.7 in .\AppData\Local\anaconda3\envs\dgc_patch_seq_20260708\Lib\site-packages (from pyabf<3.0,>=2.3->patchclamp_analysis==0.1.0) (9.1.1)
# Requirement already satisfied: colorama>=0.4 in .\AppData\Local\anaconda3\envs\dgc_patch_seq_20260708\Lib\site-packages (from pytest>=3.0.7->pyabf<3.0,>=2.3->patchclamp_analysis==0.1.0) (0.4.6)
# Requirement already satisfied: iniconfig>=1.0.1 in .\AppData\Local\anaconda3\envs\dgc_patch_seq_20260708\Lib\site-packages (from pytest>=3.0.7->pyabf<3.0,>=2.3->patchclamp_analysis==0.1.0) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in .\AppData\Local\anaconda3\envs\dgc_patch_seq_20260708\Lib\site-packages (from pytest>=3.0.7->pyabf<3.0,>=2.3->patchclamp_analysis==0.1.0) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in .\AppData\Local\anaconda3\envs\dgc_patch_seq_20260708\Lib\site-packages (from pytest>=3.0.7->pyabf<3.0,>=2.3->patchclamp_analysis==0.1.0) (2.20.0)
# Requirement already satisfied: six>=1.5 in .\AppData\Local\anaconda3\envs\dgc_patch_seq_20260708\Lib\site-packages (from python-dateutil>=2.7->matplotlib<4.0,>=3.7->patchclamp_analysis==0.1.0) (1.17.0)

# %%
# !pip install igraph
# Out:
# Collecting igraph
#   Using cached igraph-1.0.0-cp39-abi3-win_amd64.whl.metadata (4.5 kB)
# Collecting texttable>=1.6.2 (from igraph)
#   Using cached texttable-1.7.0-py2.py3-none-any.whl.metadata (9.8 kB)
# Using cached igraph-1.0.0-cp39-abi3-win_amd64.whl (3.2 MB)
# Using cached texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Installing collected packages: texttable, igraph
#
#    -------------------- ------------------- 1/2 [igraph]
#    -------------------- ------------------- 1/2 [igraph]
#    -------------------- ------------------- 1/2 [igraph]
#    -------------------- ------------------- 1/2 [igraph]
#    -------------------- ------------------- 1/2 [igraph]
#    -------------------- ------------------- 1/2 [igraph]
#    -------------------- ------------------- 1/2 [igraph]
#    -------------------- ------------------- 1/2 [igraph]
#    -------------------- ------------------- 1/2 [igraph]
#    -------------------- ------------------- 1/2 [igraph]
#    ---------------------------------------- 2/2 [igraph]
#
# Successfully installed igraph-1.0.0 texttable-1.7.0
